# %% [markdown]
# # Tuning SCREAM for RNA-ATAC data

# %% [markdown]
# For this tutorial, we will use the Cell-line SNARE-seq dataset (Original paper: https://www.nature.com/articles/s41587-019-0290-0). Briefly, there are 1047 cells with paired RNA-seq and ATAC-seq data drawn from mixtures of cultured human BJ, H1, K562 and GM12878 cell lines.

# %%
import os
# os.environ["OMP_NUM_THREADS"] = "1"
# os.environ["MKL_NUM_THREADS"] = "1"
import sys
import datetime
import pandas as pd
import numpy as np
import tensorflow as tf
import scanpy as sc
import muon as mu
import keras_tuner as kt
from functools import partial
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.optimizers import SGD

mu.set_options(pull_on_update=False)
# Out:
# 2025-09-06 16:07:52.893308: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import SCREAM

# %% [markdown]
# ## Define directories

# %% [markdown]
# Change this according to your directory structure.

# %%
mainDir = os.getcwd()
inputDir = os.path.join(mainDir, 'inputfiles')
rawDir = os.path.join(mainDir, 'inputfiles', 'raw')
processedDir = os.path.join(mainDir, 'inputfiles', 'processed')
results_dir = os.path.join(mainDir, 'results')

# %% [markdown]
# ## Define global settings

# %%
sc.set_figure_params(dpi=100, color_map='viridis_r')
# %matplotlib inline

# %%
print(f'Time before running script: {datetime.datetime.now().strftime("%d %b %Y %H:%M:%S")}')
# Out:
# Time before running script: 06 Sep 2025 16:08:57

# %%
t_start = datetime.datetime.now()

# %% [markdown]
# ## Read data

# %% [markdown]
# SCREAM requires Anndata of each modality to be provided as input to the model. In this section, we will be reading the input files and converting them to Anndata format.

# %% [markdown]
# ### Read cell metadata

# %%
cell_meta_snare = pd.read_table(os.path.join(rawDir, 'cellline', 'cell_metadata.txt'), index_col=0)
display(cell_meta_snare)
# Out:
#              cell_line
# cell
# ACTTTCTAATCA        BJ
# GAGAGAAAACCT        H1
# TACGGCTGTTAT      K562
# GACGCGTAAGTG        BJ
# GAAAGGACTGCA        BJ
# ...                ...
# GTTCTTCCTAGT        H1
# ATCCGTTCAACG        H1
# CCGACTAAGAAT      K562
# AAGCCTGGGGGC        H1
# CAGCTGGTGATG        H1
#
# [1047 rows x 1 columns]

# %% [markdown]
# ### Read RNA-seq data

# %%
rna_snare_df = pd.read_table(os.path.join(rawDir, 'cellline', 'scRNA_seq_SNARE.tsv'), index_col=0).T
rna_snare_adata = sc.AnnData(rna_snare_df, obs=cell_meta_snare)
display(rna_snare_adata)
# Out:
# AnnData object with n_obs × n_vars = 1047 × 500
#     obs: 'cell_line'

# %% [markdown]
# ### Read ATAC-seq data

# %%
atac_snare_df = pd.read_table(os.path.join(rawDir, 'cellline', 'scATAC_seq_SNARE.txt'), index_col=0).T
atac_snare_adata = sc.AnnData(atac_snare_df, obs=cell_meta_snare)
display(atac_snare_adata)
# Out:
# AnnData object with n_obs × n_vars = 1047 × 7136
#     obs: 'cell_line'

# %% [markdown]
# ## Tuning

# %% [markdown]
# ### Initialize SCREAM

# %% [markdown]
# 1. SCREAM requires a folder to be defined where it can save the model configuration, encoders and tuning results. If none provided, it will  use the current working directory.
# 2. Setting logger = True enables logging for tensorboard visualization.

# %%
model_result_dir = os.path.join(results_dir, 'scream_cellline_hyper_large_new2')
scream_model = SCREAM.models.scream.SCREAM({'RNA': rna_snare_adata, "ATAC": atac_snare_adata}, save_dir=model_result_dir, logger=True)
# Out:
# Trained models will be saved at: /scratch/g/tgu/svenkatesan/Other/SCREAM_wf/results/scream_cellline_hyper_large_new2
# MuData object with n_obs × n_vars = 1047 × 7636
#   2 modalities
#     RNA:	1047 x 500
#       obs:	'cell_line'
#     ATAC:	1047 x 7136
#       obs:	'cell_line'

# %% [markdown]
# ### Define the tuning model

# %% [markdown]
# We perform tuning to determine the optimal number of encoding layers for SAE and the dropout.
# Tuning in SCREAM uses the keras-tuner package. This requires the SAE modules to be wrapped with a keras-tuner hypermodel, which can be done as below.

# %%
class SAEHyperModel(kt.HyperModel):
    def __init__(self, X, log_dir=None, earlyStop=True, decay_epochs=50, min_lr=1e-5, **kwargs):
        super().__init__(**kwargs)
        self.X = X.copy()
        if not hasattr(self, 'name'):
            self.name = 'dataset'

        self.hyper_callbacks = []
        if earlyStop:
            self.hyper_callbacks.append(SCREAM.models.tools.CustomReduceLROnPlateau(monitor='loss', min_delta=1e-4, patience=10,
                                                                                    verbose=1, mode='auto', max_lr_epochs=decay_epochs, min_lr=min_lr))
        else:
            self.hyper_callbacks.append(LearningRateScheduler(partial(self.scheduler, factor=0.1, decay_step=decay_epochs, min_lr=min_lr)))

        if log_dir is not None:
            self.log_dir = log_dir
            self.hyper_callbacks.append(tf.keras.callbacks.TensorBoard(log_dir=os.path.join(self.log_dir, self.name, 'tb'), update_freq='epoch'))

    @staticmethod
    def scheduler(epoch, lr, factor, decay_step, min_lr):
        return np.max([np.round(lr * factor, 6), min_lr]) if epoch > 0 and epoch % decay_step == 0 else lr

    def build(self, hp):
        encoding_layer_dims = [hp.Int('layer1_units', min_value=128, max_value=1024, step=32),
                               hp.Int('layer2_units', min_value=12, max_value=256, step=32)]

        default_sae_kwargs = {'act': 'relu', 'drop_rate': hp.Float('dropout', min_value=0, max_value=0.3, step=0.1),
                              'random_seed': 201809, 'actincenter': "tanh", 'init': "glorot_uniform",
                              'use_earlyStop': True, 'suffix': '_'+self.name, 'pretrain_stacks': True}
        sae = SCREAM.models.SAE.SAE(dims=[self.X.shape[-1]] + encoding_layer_dims, **default_sae_kwargs)

        pretrain_epochs = 300
        decaying_step = 3
        if sae.stack_pretrain is True:
            sae.pretrain_stacks(self.X, epochs=int(pretrain_epochs), decaying_step=decaying_step)
            print('Copying layer-wise pretrained weights to deep autoencoders')

            for i in np.arange(sae.n_stacks):
                sae.autoencoders.get_layer(f'encoder_{i}{sae.suffix}').set_weights(sae.stacks[i].get_layer('encoder').get_weights())
                sae.autoencoders.get_layer(f'decoder_{i}{sae.suffix}').set_weights(sae.stacks[i].get_layer('decoder').get_weights())

        init_lr = hp.Float("learning_rate", min_value=0.001, max_value=0.1, step=10, sampling="log")
        sae.autoencoders.compile(optimizer=SGD(init_lr, momentum=0.9), loss='mse')

        return sae.autoencoders


def create_mod_hmodel(mdata, modality, log_dir, obsm_key=None):
    assert modality in mdata.mod_names, (f'Modality {modality} not found in mudata. Must be one of {mdata.mod_names}.')
    if obsm_key is None:
        X_all_data = mdata.mod[modality].X.copy()
    else:
        X_all_data = mdata.mod[modality].obsm[obsm_key].copy()

    return SAEHyperModel(X_all_data, log_dir=log_dir, name=modality), X_all_data


def create_joint_hmodel(mdata, modalities, log_dir, obsm_key=None):
    if modalities is not None:
        assert isinstance(modalities, list) and set(modalities).issubset(set(mdata.mod_names))
    else:
        modalities = mdata.mod_names

    ls_mat = []
    ls_names = []
    for i, modality in enumerate(modalities):
        ls_names.append([modality+'_ls_'+str(i+1) for i in np.arange(mdata.mod[modality].obsm[obsm_key].shape[1])])
        ls_mat.append(mdata.mod[modality].obsm[obsm_key])

    X_all_data = np.concatenate(ls_mat, axis=1)

    return SAEHyperModel(X_all_data, log_dir=log_dir, name='_'.join(modalities)+'_joint'), X_all_data

# %% [markdown]
# ### Stage 1: Train individual modalities

# %% [markdown]
# #### RNA SAE tuning

# %%
hyper_model, X = create_mod_hmodel(scream_model.mdata_train, modality='RNA', log_dir=model_result_dir, obsm_key=None)
tuner = kt.BayesianOptimization(hyper_model,
                                objective='loss',
                                directory=hyper_model.log_dir,
                                project_name=hyper_model.name,
                                max_trials=50)
# Out:
# Reloading Tuner from /scratch/g/tgu/svenkatesan/Other/SCREAM_wf/results/scream_cellline_hyper_large_new2/RNA/tuner0.json

# %%
display(tuner.search_space_summary(extended=True))
# Out:
# Search space summary
# Default search space size: 4
# layer1_units (Int)
# {'default': None, 'conditions': [], 'min_value': 128, 'max_value': 1024, 'step': 32, 'sampling': 'linear'}
# layer2_units (Int)
# {'default': None, 'conditions': [], 'min_value': 12, 'max_value': 256, 'step': 32, 'sampling': 'linear'}
# dropout (Float)
# {'default': 0.0, 'conditions': [], 'min_value': 0.0, 'max_value': 0.3, 'step': 0.1, 'sampling': 'linear'}
# learning_rate (Float)
# {'default': 0.001, 'conditions': [], 'min_value': 0.001, 'max_value': 0.1, 'step': 10, 'sampling': 'log'}
# None

# %%
tuner.search(X, X, epochs=300, validation_split=0.2, callbacks=hyper_model.hyper_callbacks)
tuner.results_summary()
# Out:
# Trial 50 Complete [00h 01m 15s]
# loss: 0.7833591103553772
#
# Best loss So Far: 0.7833147644996643
# Total elapsed time: 11d 04h 44m 12s
# Results summary
# Results in /scratch/g/tgu/svenkatesan/Other/SCREAM_wf/results/scream_cellline_hyper_large_new2/RNA
# Showing 10 best trials
# Objective(name="loss", direction="min")
#
# Trial 17 summary
# Hyperparameters:
# layer1_units: 1024
# layer2_units: 236
# dropout: 0.0
# learning_rate: 0.1
# Score: 0.7833147644996643
#
# Trial 19 summary
# Hyperparameters:
# layer1_units: 1024
# layer2_units: 236
# dropout: 0.0
# learning_rate: 0.1
# Score: 0.7833147644996643
#
# Trial 18 summary
# Hyperparameters:
# layer1_units: 1024
# layer2_units: 236
# dropout: 0.0
# learning_rate: 0.1
# Score: 0.7833147644996643
#
# Trial 15 summary
# Hyperparameters:
# layer1_units: 1024
# layer2_units: 236
# dropout: 0.0
# learning_rate: 0.1
# Score: 0.7833147644996643
#
# Trial 20 summary
# Hyperparameters:
# layer1_units: 1024
# layer2_units: 236
# dropout: 0.0
# learning_rate: 0.1
# Score: 0.7833147644996643
#
# Trial 16 summary
# Hyperparameters:
# layer1_units: 1024
# layer2_units: 236
# dropout: 0.0
# learning_rate: 0.1
# Score: 0.7833147644996643
#
# Trial 14 summary
# Hyperparameters:
# layer1_units: 1024
# layer2_units: 236
# dropout: 0.0
# learning_rate: 0.1
# Score: 0.7833147644996643
#
# Trial 21 summary
# Hyperparameters:
# layer1_units: 1024
# layer2_units: 236
# dropout: 0.0
# learning_rate: 0.1
# Score: 0.7833591103553772
#
# Trial 22 summary
# Hyperparameters:
# layer1_units: 1024
# layer2_units: 236
# dropout: 0.0
# learning_rate: 0.1
# Score: 0.7833591103553772
#
# Trial 23 summary
# Hyperparameters:
# layer1_units: 1024
# layer2_units: 236
# 0.0pout:
# learning_rate: 0.1
# Score: 0.7833591103553772

# %%
best_hps_rna = tuner.get_best_hyperparameters(num_trials=1)[0]
print(f"The hyperparameter search is complete. The optimal hyperparameters are: \n {best_hps_rna.values}")
# Out:
# The hyperparameter search is complete. The optimal hyperparameters are:
#  {'layer1_units': 1024, 'layer2_units': 236, 'dropout': 0.0, 'learning_rate': 0.1}

# %% [markdown]
# #### ATAC SAE tuning

# %%
hyper_model, X = create_mod_hmodel(scream_model.mdata_train, modality='ATAC', log_dir=model_result_dir, obsm_key=None)
tuner = kt.BayesianOptimization(hyper_model,
                                objective='loss',
                                directory=hyper_model.log_dir,
                                project_name=hyper_model.name, 
                                max_trials=50)
# Out:
# Reloading Tuner from /scratch/g/tgu/svenkatesan/Other/SCREAM_wf/results/scream_cellline_hyper_large_new2/ATAC/tuner0.json

# %%
display(tuner.search_space_summary(extended=True))
# Out:
# Search space summary
# Default search space size: 4
# layer1_units (Int)
# {'default': None, 'conditions': [], 'min_value': 128, 'max_value': 1024, 'step': 32, 'sampling': 'linear'}
# layer2_units (Int)
# {'default': None, 'conditions': [], 'min_value': 12, 'max_value': 256, 'step': 32, 'sampling': 'linear'}
# dropout (Float)
# {'default': 0.0, 'conditions': [], 'min_value': 0.0, 'max_value': 0.3, 'step': 0.1, 'sampling': 'linear'}
# learning_rate (Float)
# {'default': 0.001, 'conditions': [], 'min_value': 0.001, 'max_value': 0.1, 'step': 10, 'sampling': 'log'}
# None

# %%
tuner.search(X, X, epochs=300, validation_split=0.2, callbacks=hyper_model.hyper_callbacks)
tuner.results_summary()
# Out:
# Trial 50 Complete [00h 00m 39s]
# loss: 0.008814365603029728
#
# Best loss So Far: 0.008793405257165432
# Total elapsed time: 11d 04h 32m 54s
# Results summary
# Results in /scratch/g/tgu/svenkatesan/Other/SCREAM_wf/results/scream_cellline_hyper_large_new2/ATAC
# Showing 10 best trials
# Objective(name="loss", direction="min")
#
# Trial 38 summary
# Hyperparameters:
# layer1_units: 800
# layer2_units: 12
# dropout: 0.0
# learning_rate: 0.1
# Score: 0.008793405257165432
#
# Trial 24 summary
# Hyperparameters:
# layer1_units: 800
# layer2_units: 12
# dropout: 0.0
# learning_rate: 0.1
# Score: 0.008793405257165432
#
# Trial 34 summary
# Hyperparameters:
# layer1_units: 800
# layer2_units: 12
# dropout: 0.0
# learning_rate: 0.1
# Score: 0.008793405257165432
#
# Trial 41 summary
# Hyperparameters:
# layer1_units: 800
# layer2_units: 12
# dropout: 0.0
# learning_rate: 0.1
# Score: 0.008793405257165432
#
# Trial 45 summary
# Hyperparameters:
# layer1_units: 800
# layer2_units: 12
# dropout: 0.0
# learning_rate: 0.1
# Score: 0.008793406188488007
#
# Trial 46 summary
# Hyperparameters:
# layer1_units: 800
# layer2_units: 12
# dropout: 0.0
# learning_rate: 0.1
# Score: 0.008793406188488007
#
# Trial 48 summary
# Hyperparameters:
# layer1_units: 800
# layer2_units: 12
# dropout: 0.0
# learning_rate: 0.1
# Score: 0.008793406188488007
#
# Trial 17 summary
# Hyperparameters:
# layer1_units: 1024
# layer2_units: 12
# dropout: 0.2
# learning_rate: 0.1
# Score: 0.008795646950602531
#
# Trial 32 summary
# Hyperparameters:
# layer1_units: 1024
# layer2_units: 12
# dropout: 0.1
# learning_rate: 0.1
# Score: 0.0087968111038208
#
# Trial 26 summary
# Hyperparameters:
# layer1_units: 832
# layer2_units: 12
# dropout: 0.0
# learning_rate: 0.1
# Score: 0.008796961046755314

# %%
best_hps_atac = tuner.get_best_hyperparameters(num_trials=1)[0]
print(f"The hyperparameter search is complete. The optimal hyperparameters are: \n {best_hps_atac.values}")
# Out:
# The hyperparameter search is complete. The optimal hyperparameters are:
#  {'layer1_units': 800, 'layer2_units': 12, 'dropout': 0.0, 'learning_rate': 0.1}

# %% [markdown]
# #### Train modalities on best hyper parameters

# %% [markdown]
# This is the section where we use the recommendations from keras tuner for the best hyper-parameter configuration to train our model.

# %%
sae_rna = scream_model.pretrain_modality(modality='RNA', encoding_layer_dims=[1024, 236], drop_rate=0.0, batch_size=50, train_test_split=None, save_encoder=True)
# Out:
# Folder already exists
# {'drop_rate': 0.0, 'batch_size': 50}
# Model: "AE_RNA"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_RNA (InputLayer)          │ (None, 500)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ encoder_0_RNA (Dense)           │ (None, 1024)           │       513,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ encoder_1_RNA (Dense)           │ (None, 236)            │       241,900 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ decoder_1_RNA (Dense)           │ (None, 1024)           │       242,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ decoder_0_RNA (Dense)           │ (None, 500)            │       512,500 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,510,112 (5.76 MB)
#  Trainable params: 1,510,112 (5.76 MB)
#  Non-trainable params: 0 (0.00 B)
# None
# Pretraining layer 1...
# Epoch 1/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.7844 - lr: 0.1000
# Epoch 2/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7116 - lr: 0.1000
# Epoch 3/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6953 - lr: 0.1000
# Epoch 4/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6879 - lr: 0.1000
# Epoch 5/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6834 - lr: 0.1000
# Epoch 6/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6803 - lr: 0.1000
# Epoch 7/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6779 - lr: 0.1000
# Epoch 8/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6759 - lr: 0.1000
# Epoch 9/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6743 - lr: 0.1000
# Epoch 10/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6730 - lr: 0.1000
# Epoch 11/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6717 - lr: 0.1000
# Epoch 12/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6707 - lr: 0.1000
# Epoch 13/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6697 - lr: 0.1000
# Epoch 14/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6688 - lr: 0.1000
# Epoch 15/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6681 - lr: 0.1000
# Epoch 16/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6673 - lr: 0.1000
# Epoch 17/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6667 - lr: 0.1000
# Epoch 18/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6661 - lr: 0.1000
# Epoch 19/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6655 - lr: 0.1000
# Epoch 20/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6650 - lr: 0.1000
# Epoch 21/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6644 - lr: 0.1000
# Epoch 22/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6640 - lr: 0.1000
# Epoch 23/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6635 - lr: 0.1000
# Epoch 24/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6631 - lr: 0.1000
# Epoch 25/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6626 - lr: 0.1000
# Epoch 26/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6622 - lr: 0.1000
# Epoch 27/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6618 - lr: 0.1000
# Epoch 28/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6615 - lr: 0.1000
# Epoch 29/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6611 - lr: 0.1000
# Epoch 30/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6607 - lr: 0.1000
# Epoch 31/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6604 - lr: 0.1000
# Epoch 32/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6601 - lr: 0.1000
# Epoch 33/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6597 - lr: 0.1000
# Epoch 34/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6594 - lr: 0.1000
# Epoch 35/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6591 - lr: 0.1000
# Epoch 36/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6588 - lr: 0.1000
# Epoch 37/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6585 - lr: 0.1000
# Epoch 38/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6582 - lr: 0.1000
# Epoch 39/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6579 - lr: 0.1000
# Epoch 40/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6577 - lr: 0.1000
# Epoch 41/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6574 - lr: 0.1000
# Epoch 42/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6571 - lr: 0.1000
# Epoch 43/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6568 - lr: 0.1000
# Epoch 44/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6566 - lr: 0.1000
# Epoch 45/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6563 - lr: 0.1000
# Epoch 46/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6561 - lr: 0.1000
# Epoch 47/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6558 - lr: 0.1000
# Epoch 48/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6556 - lr: 0.1000
# Epoch 49/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6553 - lr: 0.1000
# Epoch 50/150
#  1/21 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.9014
# Epoch 50: ReduceLROnPlateau reducing learning rate to 0.009999999776482582
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6551 - lr: 0.1000
# Epoch 51/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6548 - lr: 0.0100
# Epoch 52/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6547 - lr: 0.0100
# Epoch 53/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6546 - lr: 0.0100
# Epoch 54/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6545 - lr: 0.0100
# Epoch 55/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6545 - lr: 0.0100
# Epoch 56/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6545 - lr: 0.0100
# Epoch 57/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6545 - lr: 0.0100
# Epoch 58/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6544 - lr: 0.0100
# Epoch 59/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6544 - lr: 0.0100
# Epoch 60/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6544 - lr: 0.0100
# Epoch 61/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6544 - lr: 0.0100
# Epoch 62/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6543 - lr: 0.0100
# Epoch 63/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6543 - lr: 0.0100
# Epoch 64/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6543 - lr: 0.0100
# Epoch 65/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6543 - lr: 0.0100
# Epoch 66/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6542 - lr: 0.0100
# Epoch 67/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6542 - lr: 0.0100
# Epoch 68/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6542 - lr: 0.0100
# Epoch 69/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6542 - lr: 0.0100
# Epoch 70/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6542 - lr: 0.0100
# Epoch 71/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6541 - lr: 0.0100
# Epoch 72/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6541 - lr: 0.0100
# Epoch 73/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6541 - lr: 0.0100
# Epoch 74/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6541 - lr: 0.0100
# Epoch 75/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6540 - lr: 0.0100
# Epoch 76/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6540 - lr: 0.0100
# Epoch 77/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6540 - lr: 0.0100
# Epoch 78/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6540 - lr: 0.0100
# Epoch 79/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6539 - lr: 0.0100
# Epoch 80/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6539 - lr: 0.0100
# Epoch 81/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6539 - lr: 0.0100
# Epoch 82/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6539 - lr: 0.0100
# Epoch 83/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6539 - lr: 0.0100
# Epoch 84/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6538 - lr: 0.0100
# Epoch 85/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6538 - lr: 0.0100
# Epoch 86/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6538 - lr: 0.0100
# Epoch 87/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6538 - lr: 0.0100
# Epoch 88/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6537 - lr: 0.0100
# Epoch 89/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6537 - lr: 0.0100
# Epoch 90/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6537 - lr: 0.0100
# Epoch 91/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6537 - lr: 0.0100
# Epoch 92/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6537 - lr: 0.0100
# Epoch 93/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6536 - lr: 0.0100
# Epoch 94/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6536 - lr: 0.0100
# Epoch 95/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6536 - lr: 0.0100
# Epoch 96/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6536 - lr: 0.0100
# Epoch 97/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6535 - lr: 0.0100
# Epoch 98/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6535 - lr: 0.0100
# Epoch 99/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6535 - lr: 0.0100
# Epoch 100/150
#  1/21 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.8994
# Epoch 100: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6535 - lr: 0.0100
# Epoch 101/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6534 - lr: 0.0010
# Epoch 102/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6534 - lr: 0.0010
# Epoch 103/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6534 - lr: 0.0010
# Epoch 104/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6534 - lr: 0.0010
# Epoch 105/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6534 - lr: 0.0010
# Epoch 106/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6534 - lr: 0.0010
# Epoch 107/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6534 - lr: 0.0010
# Epoch 108/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6534 - lr: 0.0010
# Epoch 109/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6534 - lr: 0.0010
# Epoch 110/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6534 - lr: 0.0010
# Epoch 111/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6534 - lr: 0.0010
# Layer 1 has been pretrained.
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Pretraining layer 2...
# Epoch 1/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.1223 - lr: 0.1000
# Epoch 2/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0814 - lr: 0.1000
# Epoch 3/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0650 - lr: 0.1000
# Epoch 4/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0592 - lr: 0.1000
# Epoch 5/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0558 - lr: 0.1000
# Epoch 6/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0535 - lr: 0.1000
# Epoch 7/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0517 - lr: 0.1000
# Epoch 8/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0502 - lr: 0.1000
# Epoch 9/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0485 - lr: 0.1000
# Epoch 10/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0470 - lr: 0.1000
# Epoch 11/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0460 - lr: 0.1000
# Epoch 12/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0449 - lr: 0.1000
# Epoch 13/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0426 - lr: 0.1000
# Epoch 14/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0390 - lr: 0.1000
# Epoch 15/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0366 - lr: 0.1000
# Epoch 16/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0351 - lr: 0.1000
# Epoch 17/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0342 - lr: 0.1000
# Epoch 18/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0322 - lr: 0.1000
# Epoch 19/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0307 - lr: 0.1000
# Epoch 20/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0295 - lr: 0.1000
# Epoch 21/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0287 - lr: 0.1000
# Epoch 22/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0279 - lr: 0.1000
# Epoch 23/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0273 - lr: 0.1000
# Epoch 24/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0269 - lr: 0.1000
# Epoch 25/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0266 - lr: 0.1000
# Epoch 26/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0262 - lr: 0.1000
# Epoch 27/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0252 - lr: 0.1000
# Epoch 28/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0244 - lr: 0.1000
# Epoch 29/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0239 - lr: 0.1000
# Epoch 30/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0235 - lr: 0.1000
# Epoch 31/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0230 - lr: 0.1000
# Epoch 32/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0215 - lr: 0.1000
# Epoch 33/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0204 - lr: 0.1000
# Epoch 34/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0197 - lr: 0.1000
# Epoch 35/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0192 - lr: 0.1000
# Epoch 36/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0189 - lr: 0.1000
# Epoch 37/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0187 - lr: 0.1000
# Epoch 38/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0185 - lr: 0.1000
# Epoch 39/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0183 - lr: 0.1000
# Epoch 40/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0182 - lr: 0.1000
# Epoch 41/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - lr: 0.1000
# Epoch 42/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0179 - lr: 0.1000
# Epoch 43/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0178 - lr: 0.1000
# Epoch 44/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0177 - lr: 0.1000
# Epoch 45/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0176 - lr: 0.1000
# Epoch 46/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0175 - lr: 0.1000
# Epoch 47/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0174 - lr: 0.1000
# Epoch 48/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0173 - lr: 0.1000
# Epoch 49/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0171 - lr: 0.1000
# Epoch 50/150
#  1/21 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0226
# Epoch 50: ReduceLROnPlateau reducing learning rate to 0.009999999776482582
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0170 - lr: 0.1000
# Epoch 51/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0168 - lr: 0.0100
# Epoch 52/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0168 - lr: 0.0100
# Epoch 53/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0167 - lr: 0.0100
# Epoch 54/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0167 - lr: 0.0100
# Epoch 55/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0167 - lr: 0.0100
# Epoch 56/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0167 - lr: 0.0100
# Epoch 57/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0167 - lr: 0.0100
# Epoch 58/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0167 - lr: 0.0100
# Epoch 59/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0167 - lr: 0.0100
# Epoch 60/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0167 - lr: 0.0100
# Epoch 61/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0166 - lr: 0.0100
# Epoch 62/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0166 - lr: 0.0100
# Epoch 63/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0166 - lr: 0.0100
# Epoch 64/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0166 - lr: 0.0100
# Epoch 65/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0166 - lr: 0.0100
# Epoch 66/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0166 - lr: 0.0100
# Epoch 67/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0166 - lr: 0.0100
# Epoch 68/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0166 - lr: 0.0100
# Epoch 69/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0166 - lr: 0.0100
# Epoch 70/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0165 - lr: 0.0100
# Epoch 71/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0165 - lr: 0.0100
# Epoch 72/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0165 - lr: 0.0100
# Epoch 73/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0165 - lr: 0.0100
# Epoch 74/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0165 - lr: 0.0100
# Epoch 75/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0165 - lr: 0.0100
# Epoch 76/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0165 - lr: 0.0100
# Epoch 77/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0165 - lr: 0.0100
# Epoch 78/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0165 - lr: 0.0100
# Epoch 79/150
#  1/21 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0221
# Epoch 79: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0165 - lr: 0.0100
# Epoch 80/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0164 - lr: 0.0010
# Epoch 81/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0165 - lr: 0.0010
# Epoch 82/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0165 - lr: 0.0010
# Epoch 83/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0164 - lr: 0.0010
# Epoch 84/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0164 - lr: 0.0010
# Epoch 85/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0164 - lr: 0.0010
# Epoch 86/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0164 - lr: 0.0010
# Epoch 87/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0164 - lr: 0.0010
# Epoch 88/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0164 - lr: 0.0010
# Epoch 89/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0164 - lr: 0.0010
# Epoch 90/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0164 - lr: 0.0010
# Layer 2 has been pretrained.
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Copying layer-wise pretrained weights to deep autoencoders
# Fine-tuning autoencoder end-to-end
# Epoch 1/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.6677 - lr: 0.1000
# Epoch 2/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6661 - lr: 0.1000
# Epoch 3/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6653 - lr: 0.1000
# Epoch 4/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6647 - lr: 0.1000
# Epoch 5/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6643 - lr: 0.1000
# Epoch 6/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6640 - lr: 0.1000
# Epoch 7/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6637 - lr: 0.1000
# Epoch 8/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6635 - lr: 0.1000
# Epoch 9/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6632 - lr: 0.1000
# Epoch 10/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6630 - lr: 0.1000
# Epoch 11/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6628 - lr: 0.1000
# Epoch 12/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6626 - lr: 0.1000
# Epoch 13/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6624 - lr: 0.1000
# Epoch 14/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6622 - lr: 0.1000
# Epoch 15/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6620 - lr: 0.1000
# Epoch 16/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6619 - lr: 0.1000
# Epoch 17/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6617 - lr: 0.1000
# Epoch 18/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6615 - lr: 0.1000
# Epoch 19/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6614 - lr: 0.1000
# Epoch 20/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6612 - lr: 0.1000
# Epoch 21/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6610 - lr: 0.1000
# Epoch 22/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6609 - lr: 0.1000
# Epoch 23/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6607 - lr: 0.1000
# Epoch 24/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6606 - lr: 0.1000
# Epoch 25/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6604 - lr: 0.1000
# Epoch 26/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6603 - lr: 0.1000
# Epoch 27/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6601 - lr: 0.1000
# Epoch 28/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6600 - lr: 0.1000
# Epoch 29/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6599 - lr: 0.1000
# Epoch 30/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6597 - lr: 0.1000
# Epoch 31/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6596 - lr: 0.1000
# Epoch 32/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6594 - lr: 0.1000
# Epoch 33/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6593 - lr: 0.1000
# Epoch 34/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6591 - lr: 0.1000
# Epoch 35/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6590 - lr: 0.1000
# Epoch 36/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6589 - lr: 0.1000
# Epoch 37/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6587 - lr: 0.1000
# Epoch 38/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6586 - lr: 0.1000
# Epoch 39/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6585 - lr: 0.1000
# Epoch 40/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6583 - lr: 0.1000
# Epoch 41/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6582 - lr: 0.1000
# Epoch 42/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6581 - lr: 0.1000
# Epoch 43/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6579 - lr: 0.1000
# Epoch 44/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6578 - lr: 0.1000
# Epoch 45/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6577 - lr: 0.1000
# Epoch 46/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6576 - lr: 0.1000
# Epoch 47/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6574 - lr: 0.1000
# Epoch 48/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6573 - lr: 0.1000
# Epoch 49/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6572 - lr: 0.1000
# Epoch 50/300
#  1/21 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.9035
# Epoch 50: ReduceLROnPlateau reducing learning rate to 0.009999999776482582
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6571 - lr: 0.1000
# Epoch 51/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6568 - lr: 0.0100
# Epoch 52/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6568 - lr: 0.0100
# Epoch 53/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6567 - lr: 0.0100
# Epoch 54/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6567 - lr: 0.0100
# Epoch 55/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6567 - lr: 0.0100
# Epoch 56/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6567 - lr: 0.0100
# Epoch 57/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6566 - lr: 0.0100
# Epoch 58/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6566 - lr: 0.0100
# Epoch 59/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6566 - lr: 0.0100
# Epoch 60/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6566 - lr: 0.0100
# Epoch 61/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6566 - lr: 0.0100
# Epoch 62/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6566 - lr: 0.0100
# Epoch 63/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6566 - lr: 0.0100
# Epoch 64/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6566 - lr: 0.0100
# Epoch 65/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6565 - lr: 0.0100
# Epoch 66/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6565 - lr: 0.0100
# Epoch 67/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6565 - lr: 0.0100
# Epoch 68/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6565 - lr: 0.0100
# Epoch 69/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6565 - lr: 0.0100
# Epoch 70/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6565 - lr: 0.0100
# Epoch 71/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6565 - lr: 0.0100
# Epoch 72/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6565 - lr: 0.0100
# Epoch 73/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6564 - lr: 0.0100
# Epoch 74/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6564 - lr: 0.0100
# Epoch 75/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6564 - lr: 0.0100
# Epoch 76/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6564 - lr: 0.0100
# Epoch 77/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6564 - lr: 0.0100
# Epoch 78/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6564 - lr: 0.0100
# Epoch 79/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6564 - lr: 0.0100
# Epoch 80/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6564 - lr: 0.0100
# Epoch 81/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6563 - lr: 0.0100
# Epoch 82/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6563 - lr: 0.0100
# Epoch 83/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6563 - lr: 0.0100
# Epoch 84/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6563 - lr: 0.0100
# Epoch 85/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6563 - lr: 0.0100
# Epoch 86/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6563 - lr: 0.0100
# Epoch 87/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6563 - lr: 0.0100
# Epoch 88/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6563 - lr: 0.0100
# Epoch 89/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6562 - lr: 0.0100
# Epoch 90/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6562 - lr: 0.0100
# Epoch 91/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6562 - lr: 0.0100
# Epoch 92/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6562 - lr: 0.0100
# Epoch 93/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6562 - lr: 0.0100
# Epoch 94/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6562 - lr: 0.0100
# Epoch 95/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6562 - lr: 0.0100
# Epoch 96/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6562 - lr: 0.0100
# Epoch 97/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6562 - lr: 0.0100
# Epoch 98/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6561 - lr: 0.0100
# Epoch 99/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6561 - lr: 0.0100
# Epoch 100/300
#  1/21 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.9024
# Epoch 100: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6561 - lr: 0.0100
# Epoch 101/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6561 - lr: 0.0010
# Epoch 102/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6561 - lr: 0.0010
# Epoch 103/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6561 - lr: 0.0010
# Epoch 104/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6561 - lr: 0.0010
# Epoch 105/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6561 - lr: 0.0010
# Epoch 106/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6561 - lr: 0.0010
# Epoch 107/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6561 - lr: 0.0010
# Epoch 108/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6561 - lr: 0.0010
# Epoch 109/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6561 - lr: 0.0010
# Epoch 110/300
#  1/21 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.9024
# Epoch 110: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6561 - lr: 0.0010
# Epoch 111/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6561 - lr: 1.0000e-04
# Epoch 112/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6561 - lr: 1.0000e-04
# Epoch 113/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6561 - lr: 1.0000e-04
# Epoch 114/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6561 - lr: 1.0000e-04
# Epoch 115/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6561 - lr: 1.0000e-04
# Epoch 116/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6561 - lr: 1.0000e-04
# Epoch 117/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6561 - lr: 1.0000e-04
# Epoch 118/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6561 - lr: 1.0000e-04
# Epoch 119/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6561 - lr: 1.0000e-04
# Epoch 120/300
#  1/21 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.9024
# Epoch 120: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6561 - lr: 1.0000e-04
# Epoch 121/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6561 - lr: 1.0000e-05
# Epoch 122/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6561 - lr: 1.0000e-05
# Epoch 123/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6561 - lr: 1.0000e-05
# Epoch 124/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6561 - lr: 1.0000e-05
# Epoch 125/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6561 - lr: 1.0000e-05
# Epoch 126/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6561 - lr: 1.0000e-05
# Epoch 127/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6561 - lr: 1.0000e-05
# Epoch 128/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6561 - lr: 1.0000e-05
# Epoch 129/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6561 - lr: 1.0000e-05
# Epoch 130/300
#  1/21 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.9024
# Epoch 130: ReduceLROnPlateau reducing learning rate to 1e-06.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6561 - lr: 1.0000e-05
# Epoch 131/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6561 - lr: 1.0000e-06
# Epoch 132/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6561 - lr: 1.0000e-06
# Epoch 133/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6561 - lr: 1.0000e-06
# Epoch 134/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6561 - lr: 1.0000e-06
# Epoch 135/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6561 - lr: 1.0000e-06
# Epoch 136/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6561 - lr: 1.0000e-06
# Epoch 137/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6561 - lr: 1.0000e-06
# Epoch 138/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6561 - lr: 1.0000e-06
# Epoch 139/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6561 - lr: 1.0000e-06
# Epoch 140/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6561 - lr: 1.0000e-06
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step

# %%
# SCREAM.models.tools.plot_architecture(sae_rna.autoencoders, to_file=os.path.join(model_result_dir, 'rna_ae.svg'), rankdir='LR')

# %%
sae_atac = scream_model.pretrain_modality(modality='ATAC', encoding_layer_dims=[800, 12], drop_rate=0.0, batch_size=50, train_test_split=None, save_encoder=True)
# Out:
# Folder already exists
# {'drop_rate': 0.0, 'batch_size': 50}
# Model: "AE_ATAC"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_ATAC (InputLayer)         │ (None, 7136)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ encoder_0_ATAC (Dense)          │ (None, 800)            │     5,709,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ encoder_1_ATAC (Dense)          │ (None, 12)             │         9,612 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ decoder_1_ATAC (Dense)          │ (None, 800)            │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ decoder_0_ATAC (Dense)          │ (None, 7136)           │     5,715,936 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 11,445,548 (43.66 MB)
#  Trainable params: 11,445,548 (43.66 MB)
#  Non-trainable params: 0 (0.00 B)
# None
# Pretraining layer 1...
# Epoch 1/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.0101 - lr: 0.1000
# Epoch 2/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0101 - lr: 0.1000
# Epoch 3/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0100 - lr: 0.1000
# Epoch 4/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0099 - lr: 0.1000
# Epoch 5/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0099 - lr: 0.1000
# Epoch 6/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0098 - lr: 0.1000
# Epoch 7/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0098 - lr: 0.1000
# Epoch 8/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0097 - lr: 0.1000
# Epoch 9/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0097 - lr: 0.1000
# Epoch 10/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0096 - lr: 0.1000
# Epoch 11/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0096 - lr: 0.1000
# Epoch 12/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0096 - lr: 0.1000
# Epoch 13/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0095 - lr: 0.1000
# Epoch 14/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0095 - lr: 0.1000
# Epoch 15/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0095 - lr: 0.1000
# Epoch 16/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0094 - lr: 0.1000
# Epoch 17/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0094 - lr: 0.1000
# Epoch 18/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0094 - lr: 0.1000
# Epoch 19/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0094 - lr: 0.1000
# Epoch 20/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0093 - lr: 0.1000
# Epoch 21/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0093 - lr: 0.1000
# Epoch 22/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0093 - lr: 0.1000
# Epoch 23/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0093 - lr: 0.1000
# Epoch 24/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0093 - lr: 0.1000
# Epoch 25/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0092 - lr: 0.1000
# Epoch 26/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0092 - lr: 0.1000
# Epoch 27/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0092 - lr: 0.1000
# Epoch 28/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0092 - lr: 0.1000
# Epoch 29/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0092 - lr: 0.1000
# Epoch 30/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0092 - lr: 0.1000
# Epoch 31/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0091 - lr: 0.1000
# Epoch 32/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0091 - lr: 0.1000
# Epoch 33/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0091 - lr: 0.1000
# Epoch 34/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0091 - lr: 0.1000
# Epoch 35/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0091 - lr: 0.1000
# Epoch 36/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0091 - lr: 0.1000
# Epoch 37/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0091 - lr: 0.1000
# Epoch 38/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0091 - lr: 0.1000
# Epoch 39/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0090 - lr: 0.1000
# Epoch 40/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0090 - lr: 0.1000
# Epoch 41/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0090 - lr: 0.1000
# Epoch 42/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0090 - lr: 0.1000
# Epoch 43/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0090 - lr: 0.1000
# Epoch 44/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0090 - lr: 0.1000
# Epoch 45/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0090 - lr: 0.1000
# Epoch 46/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0090 - lr: 0.1000
# Epoch 47/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0090 - lr: 0.1000
# Epoch 48/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0090 - lr: 0.1000
# Epoch 49/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0089 - lr: 0.1000
# Epoch 50/150
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0089
# Epoch 50: ReduceLROnPlateau reducing learning rate to 0.009999999776482582
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0089 - lr: 0.1000
# Epoch 51/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0089 - lr: 0.0100
# Epoch 52/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0089 - lr: 0.0100
# Epoch 53/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0089 - lr: 0.0100
# Epoch 54/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0089 - lr: 0.0100
# Epoch 55/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0089 - lr: 0.0100
# Epoch 56/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0089 - lr: 0.0100
# Epoch 57/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0089 - lr: 0.0100
# Epoch 58/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0089 - lr: 0.0100
# Epoch 59/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0089 - lr: 0.0100
# Epoch 60/150
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0089
# Epoch 60: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0089 - lr: 0.0100
# Epoch 61/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0089 - lr: 0.0010
# Epoch 62/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0089 - lr: 0.0010
# Epoch 63/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0089 - lr: 0.0010
# Epoch 64/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0089 - lr: 0.0010
# Epoch 65/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0089 - lr: 0.0010
# Epoch 66/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0089 - lr: 0.0010
# Epoch 67/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0089 - lr: 0.0010
# Epoch 68/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0089 - lr: 0.0010
# Epoch 69/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0089 - lr: 0.0010
# Epoch 70/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0089 - lr: 0.0010
# Layer 1 has been pretrained.
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Pretraining layer 2...
# Epoch 1/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0034 - lr: 0.1000
# Epoch 2/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0034 - lr: 0.1000
# Epoch 3/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0034 - lr: 0.1000
# Epoch 4/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0034 - lr: 0.1000
# Epoch 5/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0034 - lr: 0.1000
# Epoch 6/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0034 - lr: 0.1000
# Epoch 7/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0034 - lr: 0.1000
# Epoch 8/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - lr: 0.1000
# Epoch 9/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - lr: 0.1000
# Epoch 10/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - lr: 0.1000
# Epoch 11/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - lr: 0.1000
# Epoch 12/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - lr: 0.1000
# Epoch 13/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - lr: 0.1000
# Epoch 14/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - lr: 0.1000
# Epoch 15/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - lr: 0.1000
# Epoch 16/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - lr: 0.1000
# Epoch 17/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - lr: 0.1000
# Epoch 18/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - lr: 0.1000
# Epoch 19/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - lr: 0.1000
# Epoch 20/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - lr: 0.1000
# Epoch 21/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - lr: 0.1000
# Epoch 22/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - lr: 0.1000
# Epoch 23/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - lr: 0.1000
# Epoch 24/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - lr: 0.1000
# Epoch 25/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - lr: 0.1000
# Epoch 26/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - lr: 0.1000
# Epoch 27/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - lr: 0.1000
# Epoch 28/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - lr: 0.1000
# Epoch 29/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - lr: 0.1000
# Epoch 30/150
#  1/21 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0027
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.009999999776482582.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - lr: 0.1000
# Epoch 31/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - lr: 0.0100
# Epoch 32/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - lr: 0.0100
# Epoch 33/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - lr: 0.0100
# Epoch 34/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - lr: 0.0100
# Epoch 35/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - lr: 0.0100
# Epoch 36/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - lr: 0.0100
# Epoch 37/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - lr: 0.0100
# Epoch 38/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - lr: 0.0100
# Epoch 39/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - lr: 0.0100
# Epoch 40/150
#  1/21 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0027
# Epoch 40: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - lr: 0.0100
# Epoch 41/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - lr: 0.0010
# Epoch 42/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - lr: 0.0010
# Epoch 43/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - lr: 0.0010
# Epoch 44/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - lr: 0.0010
# Epoch 45/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - lr: 0.0010
# Epoch 46/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - lr: 0.0010
# Epoch 47/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - lr: 0.0010
# Epoch 48/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - lr: 0.0010
# Epoch 49/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - lr: 0.0010
# Epoch 50/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - lr: 0.0010
# Layer 2 has been pretrained.
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Copying layer-wise pretrained weights to deep autoencoders
# Fine-tuning autoencoder end-to-end
# Epoch 1/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0085 - lr: 0.1000
# Epoch 2/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0085 - lr: 0.1000
# Epoch 3/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0085 - lr: 0.1000
# Epoch 4/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0085 - lr: 0.1000
# Epoch 5/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0085 - lr: 0.1000
# Epoch 6/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084 - lr: 0.1000
# Epoch 7/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084 - lr: 0.1000
# Epoch 8/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084 - lr: 0.1000
# Epoch 9/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084 - lr: 0.1000
# Epoch 10/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084 - lr: 0.1000
# Epoch 11/300
# 15/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0083
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.009999999776482582.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084 - lr: 0.1000
# Epoch 12/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084 - lr: 0.0100
# Epoch 13/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084 - lr: 0.0100
# Epoch 14/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084 - lr: 0.0100
# Epoch 15/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084 - lr: 0.0100
# Epoch 16/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084 - lr: 0.0100
# Epoch 17/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084 - lr: 0.0100
# Epoch 18/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084 - lr: 0.0100
# Epoch 19/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084 - lr: 0.0100
# Epoch 20/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084 - lr: 0.0100
# Epoch 21/300
# 15/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0083
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084 - lr: 0.0100
# Epoch 22/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084 - lr: 0.0010
# Epoch 23/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084 - lr: 0.0010
# Epoch 24/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084 - lr: 0.0010
# Epoch 25/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084 - lr: 0.0010
# Epoch 26/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084 - lr: 0.0010
# Epoch 27/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084 - lr: 0.0010
# Epoch 28/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084 - lr: 0.0010
# Epoch 29/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084 - lr: 0.0010
# Epoch 30/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084 - lr: 0.0010
# Epoch 31/300
# 15/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0083
# Epoch 31: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084 - lr: 0.0010
# Epoch 32/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084 - lr: 1.0000e-04
# Epoch 33/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084 - lr: 1.0000e-04
# Epoch 34/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084 - lr: 1.0000e-04
# Epoch 35/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084 - lr: 1.0000e-04
# Epoch 36/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084 - lr: 1.0000e-04
# Epoch 37/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084 - lr: 1.0000e-04
# Epoch 38/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084 - lr: 1.0000e-04
# Epoch 39/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084 - lr: 1.0000e-04
# Epoch 40/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084 - lr: 1.0000e-04
# Epoch 41/300
# 15/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0083
# Epoch 41: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084 - lr: 1.0000e-04
# Epoch 42/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084 - lr: 1.0000e-05
# Epoch 43/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084 - lr: 1.0000e-05
# Epoch 44/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084 - lr: 1.0000e-05
# Epoch 45/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084 - lr: 1.0000e-05
# Epoch 46/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084 - lr: 1.0000e-05
# Epoch 47/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084 - lr: 1.0000e-05
# Epoch 48/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084 - lr: 1.0000e-05
# Epoch 49/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084 - lr: 1.0000e-05
# Epoch 50/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084 - lr: 1.0000e-05
# Epoch 51/300
# 15/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0083
# Epoch 51: ReduceLROnPlateau reducing learning rate to 1e-06.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084 - lr: 1.0000e-05
# Epoch 52/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084 - lr: 1.0000e-06
# Epoch 53/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084 - lr: 1.0000e-06
# Epoch 54/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084 - lr: 1.0000e-06
# Epoch 55/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084 - lr: 1.0000e-06
# Epoch 56/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084 - lr: 1.0000e-06
# Epoch 57/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084 - lr: 1.0000e-06
# Epoch 58/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084 - lr: 1.0000e-06
# Epoch 59/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084 - lr: 1.0000e-06
# Epoch 60/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084 - lr: 1.0000e-06
# Epoch 61/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084 - lr: 1.0000e-06
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step

# %%
# SCREAM.models.tools.plot_architecture(sae_atac.autoencoders, to_file=os.path.join(model_result_dir, 'atac_ae.svg'), rankdir='LR')

# %% [markdown]
# ### Stage 2: Train on joint latent space

# %% [markdown]
# In this section, we can tune our joint SAE module which takes the fused modality inputs as features.

# %% [markdown]
# #### Tuning joint space

# %%
hyper_model, X = create_joint_hmodel(scream_model.mdata_train, modalities=['RNA', 'ATAC'], log_dir=model_result_dir, obsm_key='X_desc_ls')
tuner = kt.BayesianOptimization(hyper_model,
                                objective='loss',
                                directory=hyper_model.log_dir,
                                project_name=hyper_model.name,
                                max_trials=50)
# Out:
# Reloading Tuner from /scratch/g/tgu/svenkatesan/Other/SCREAM_wf/results/scream_cellline_hyper_large_new2/RNA_ATAC_joint/tuner0.json

# %%
display(tuner.search_space_summary(extended=True))
# Out:
# Search space summary
# Default search space size: 4
# layer1_units (Int)
# {'default': None, 'conditions': [], 'min_value': 128, 'max_value': 1024, 'step': 32, 'sampling': 'linear'}
# layer2_units (Int)
# {'default': None, 'conditions': [], 'min_value': 12, 'max_value': 256, 'step': 32, 'sampling': 'linear'}
# dropout (Float)
# {'default': 0.0, 'conditions': [], 'min_value': 0.0, 'max_value': 0.3, 'step': 0.1, 'sampling': 'linear'}
# learning_rate (Float)
# {'default': 0.001, 'conditions': [], 'min_value': 0.001, 'max_value': 0.1, 'step': 10, 'sampling': 'log'}
# None

# %%
tuner.search(X, X, epochs=300, validation_split=0.2, callbacks=hyper_model.hyper_callbacks)
tuner.results_summary()
# Out:
# Trial 50 Complete [00h 00m 53s]
# loss: 0.008199234493076801
#
# Best loss So Far: 0.008199234493076801
# Total elapsed time: 11d 04h 04m 48s
# Results summary
# Results in /scratch/g/tgu/svenkatesan/Other/SCREAM_wf/results/scream_cellline_hyper_large_new2/RNA_ATAC_joint
# Showing 10 best trials
# Objective(name="loss", direction="min")
#
# Trial 20 summary
# Hyperparameters:
# layer1_units: 1024
# layer2_units: 236
# dropout: 0.0
# learning_rate: 0.1
# Score: 0.008199234493076801
#
# Trial 21 summary
# Hyperparameters:
# layer1_units: 1024
# layer2_units: 236
# dropout: 0.0
# learning_rate: 0.1
# Score: 0.008199234493076801
#
# Trial 22 summary
# Hyperparameters:
# layer1_units: 1024
# layer2_units: 236
# dropout: 0.0
# learning_rate: 0.1
# Score: 0.008199234493076801
#
# Trial 23 summary
# Hyperparameters:
# layer1_units: 1024
# layer2_units: 236
# dropout: 0.0
# learning_rate: 0.1
# Score: 0.008199234493076801
#
# Trial 24 summary
# Hyperparameters:
# layer1_units: 1024
# layer2_units: 236
# dropout: 0.0
# learning_rate: 0.1
# Score: 0.008199234493076801
#
# Trial 25 summary
# Hyperparameters:
# layer1_units: 1024
# layer2_units: 236
# dropout: 0.0
# 0.1rning_rate:
# Score: 0.008199234493076801
#
# Trial 26 summary
# Hyperparameters:
# layer1_units: 1024
# layer2_units: 236
# dropout: 0.0
# learning_rate: 0.1
# Score: 0.008199234493076801
#
# Trial 27 summary
# Hyperparameters:
# layer1_units: 1024
# layer2_units: 236
# dropout: 0.0
# learning_rate: 0.1
# Score: 0.008199234493076801
#
# Trial 28 summary
# Hyperparameters:
# layer1_units: 1024
# layer2_units: 236
# dropout: 0.0
# learning_rate: 0.1
# Score: 0.008199234493076801
#
# Trial 29 summary
# Hyperparameters:
# layer1_units: 1024
# layer2_units: 236
# dropout: 0.0
# learning_rate: 0.1
# Score: 0.008199234493076801

# %%
best_hps_joint = tuner.get_best_hyperparameters(num_trials=1)[0]
print(f"The hyperparameter search is complete. The optimal hyperparameters are: \n {best_hps_joint.values}")
# Out:
# The hyperparameter search is complete. The optimal hyperparameters are:
#  {'layer1_units': 1024, 'layer2_units': 236, 'dropout': 0.0, 'learning_rate': 0.1}

# %% [markdown]
# #### Training on best hyper parameters

# %% [markdown]
# leiden_res defines the resolution of clustering. If multiple are provided, the model will train an autoencoder once and then use the encoder portion in the clustering module for each resolution individually.

# %%
default_scream_opts = {'tol': 0.0001, 'n_neighbors': 15,
                       'batch_size': 50, 'method': 'leiden',
                       'do_tsne': True, 'tsne_kwargs': {'learning_rate': 200}, 'gpu_device': None,
                       'save_encoder_weights': False, 'use_ae_weights': False,
                       'do_umap': True, 'save_clustering_model': True}

# %%
leiden_res = list(np.linspace(0.1, 1, num=10).round(decimals=2))
leiden_res.append(0.05)
ae_combined = scream_model.train_joint(modalities=None, clustering_resolutions=leiden_res, encoding_layer_dims=[1024, 236], **default_scream_opts)
# Out:
# Folder already exists
# {'tol': 0.0001, 'n_neighbors': 15, 'batch_size': 50, 'method': 'leiden', 'save_encoder_weights': False, 'use_ae_weights': False}
# {'learning_rate': 200}
# The number of available cores is 40.
# The number of cores used for training is 10.
# Start to process resolution: 0.1
# Training will be done on CPU.
# Runtime for resolution 0.1 (HH:MM:SS): 0:00:00.000013
# Rerunning autoencoder
# Logged at /scratch/g/tgu/svenkatesan/Other/SCREAM_wf/results/scream_cellline_hyper_large_new2/RNA_ATAC_joint/pretrain
# Pretraining layer 1...
# Epoch 1/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - loss: 0.1064 - lr: 0.1000
# Epoch 2/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0579 - lr: 0.1000
# Epoch 3/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0454 - lr: 0.1000
# Epoch 4/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0402 - lr: 0.1000
# Epoch 5/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0375 - lr: 0.1000
# Epoch 6/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0356 - lr: 0.1000
# Epoch 7/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0343 - lr: 0.1000
# Epoch 8/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0328 - lr: 0.1000
# Epoch 9/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0319 - lr: 0.1000
# Epoch 10/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0312 - lr: 0.1000
# Epoch 11/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0303 - lr: 0.1000
# Epoch 12/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0296 - lr: 0.1000
# Epoch 13/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0290 - lr: 0.1000
# Epoch 14/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0285 - lr: 0.1000
# Epoch 15/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0278 - lr: 0.1000
# Epoch 16/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0276 - lr: 0.1000
# Epoch 17/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0272 - lr: 0.1000
# Epoch 18/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0267 - lr: 0.1000
# Epoch 19/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0262 - lr: 0.1000
# Epoch 20/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0259 - lr: 0.1000
# Epoch 21/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0256 - lr: 0.1000
# Epoch 22/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0252 - lr: 0.1000
# Epoch 23/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0249 - lr: 0.1000
# Epoch 24/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0244 - lr: 0.1000
# Epoch 25/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0244 - lr: 0.1000
# Epoch 26/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0241 - lr: 0.1000
# Epoch 27/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0240 - lr: 0.1000
# Epoch 28/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0237 - lr: 0.1000
# Epoch 29/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0235 - lr: 0.1000
# Epoch 30/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0232 - lr: 0.1000
# Epoch 31/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0231 - lr: 0.1000
# Epoch 32/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0230 - lr: 0.1000
# Epoch 33/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0226 - lr: 0.1000
# Epoch 34/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0226 - lr: 0.1000
# Epoch 35/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0224 - lr: 0.1000
# Epoch 36/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0222 - lr: 0.1000
# Epoch 37/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0221 - lr: 0.1000
# Epoch 38/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0218 - lr: 0.1000
# Epoch 39/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0217 - lr: 0.1000
# Epoch 40/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0215 - lr: 0.1000
# Epoch 41/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0214 - lr: 0.1000
# Epoch 42/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0212 - lr: 0.1000
# Epoch 43/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0211 - lr: 0.1000
# Epoch 44/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0209 - lr: 0.1000
# Epoch 45/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0207 - lr: 0.1000
# Epoch 46/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0206 - lr: 0.1000
# Epoch 47/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0205 - lr: 0.1000
# Epoch 48/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0205 - lr: 0.1000
# Epoch 49/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0202 - lr: 0.1000
# Epoch 50/150
#  1/21 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0261
# Epoch 50: ReduceLROnPlateau reducing learning rate to 0.009999999776482582
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0203 - lr: 0.1000
# Epoch 51/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0200 - lr: 0.0100
# Epoch 52/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0201 - lr: 0.0100
# Epoch 53/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0200 - lr: 0.0100
# Epoch 54/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0200 - lr: 0.0100
# Epoch 55/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0200 - lr: 0.0100
# Epoch 56/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0199 - lr: 0.0100
# Epoch 57/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0200 - lr: 0.0100
# Epoch 58/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0200 - lr: 0.0100
# Epoch 59/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0199 - lr: 0.0100
# Epoch 60/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0200 - lr: 0.0100
# Epoch 61/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0199 - lr: 0.0100
# Epoch 62/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0199 - lr: 0.0100
# Epoch 63/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0200 - lr: 0.0100
# Epoch 64/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0199 - lr: 0.0100
# Epoch 65/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0198 - lr: 0.0100
# Epoch 66/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0198 - lr: 0.0100
# Epoch 67/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0198 - lr: 0.0100
# Epoch 68/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0198 - lr: 0.0100
# Epoch 69/150
#  1/21 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0251
# Epoch 69: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0199 - lr: 0.0100
# Epoch 70/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0199 - lr: 0.0010
# Epoch 71/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0198 - lr: 0.0010
# Epoch 72/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0198 - lr: 0.0010
# Epoch 73/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0198 - lr: 0.0010
# Epoch 74/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0198 - lr: 0.0010
# Epoch 75/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0197 - lr: 0.0010
# Epoch 76/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0199 - lr: 0.0010
# Epoch 77/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0198 - lr: 0.0010
# Epoch 78/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0198 - lr: 0.0010
# Epoch 79/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0198 - lr: 0.0010
# Epoch 80/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0199 - lr: 0.0010
# Epoch 81/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0198 - lr: 0.0010
# Epoch 82/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0198 - lr: 0.0010
# Epoch 83/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0198 - lr: 0.0010
# Epoch 84/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0200 - lr: 0.0010
# Epoch 85/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0198 - lr: 0.0010
# Layer 1 has been pretrained.
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Pretraining layer 2...
# Epoch 1/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - loss: 0.0107 - lr: 0.1000
# Epoch 2/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0103 - lr: 0.1000
# Epoch 3/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0099 - lr: 0.1000
# Epoch 4/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0096 - lr: 0.1000
# Epoch 5/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0093 - lr: 0.1000
# Epoch 6/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0091 - lr: 0.1000
# Epoch 7/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0088 - lr: 0.1000
# Epoch 8/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0086 - lr: 0.1000
# Epoch 9/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0085 - lr: 0.1000
# Epoch 10/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0083 - lr: 0.1000
# Epoch 11/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0081 - lr: 0.1000
# Epoch 12/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0080 - lr: 0.1000
# Epoch 13/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0078 - lr: 0.1000
# Epoch 14/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0077 - lr: 0.1000
# Epoch 15/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0075 - lr: 0.1000
# Epoch 16/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0074 - lr: 0.1000
# Epoch 17/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0073 - lr: 0.1000
# Epoch 18/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0071 - lr: 0.1000
# Epoch 19/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0070 - lr: 0.1000
# Epoch 20/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0069 - lr: 0.1000
# Epoch 21/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0068 - lr: 0.1000
# Epoch 22/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0067 - lr: 0.1000
# Epoch 23/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0066 - lr: 0.1000
# Epoch 24/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0065 - lr: 0.1000
# Epoch 25/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0064 - lr: 0.1000
# Epoch 26/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0063 - lr: 0.1000
# Epoch 27/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0062 - lr: 0.1000
# Epoch 28/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0061 - lr: 0.1000
# Epoch 29/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0060 - lr: 0.1000
# Epoch 30/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0059 - lr: 0.1000
# Epoch 31/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0058 - lr: 0.1000
# Epoch 32/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0058 - lr: 0.1000
# Epoch 33/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0057 - lr: 0.1000
# Epoch 34/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0057 - lr: 0.1000
# Epoch 35/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0056 - lr: 0.1000
# Epoch 36/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0055 - lr: 0.1000
# Epoch 37/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0054 - lr: 0.1000
# Epoch 38/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0053 - lr: 0.1000
# Epoch 39/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0053 - lr: 0.1000
# Epoch 40/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0052 - lr: 0.1000
# Epoch 41/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0052 - lr: 0.1000
# Epoch 42/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0051 - lr: 0.1000
# Epoch 43/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0051 - lr: 0.1000
# Epoch 44/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0050 - lr: 0.1000
# Epoch 45/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0049 - lr: 0.1000
# Epoch 46/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0049 - lr: 0.1000
# Epoch 47/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0048 - lr: 0.1000
# Epoch 48/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0048 - lr: 0.1000
# Epoch 49/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0048 - lr: 0.1000
# Epoch 50/150
#  1/21 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0068
# Epoch 50: ReduceLROnPlateau reducing learning rate to 0.009999999776482582
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0047 - lr: 0.1000
# Epoch 51/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0047 - lr: 0.0100
# Epoch 52/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0047 - lr: 0.0100
# Epoch 53/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0047 - lr: 0.0100
# Epoch 54/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0046 - lr: 0.0100
# Epoch 55/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0047 - lr: 0.0100
# Epoch 56/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0047 - lr: 0.0100
# Epoch 57/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0047 - lr: 0.0100
# Epoch 58/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0047 - lr: 0.0100
# Epoch 59/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0046 - lr: 0.0100
# Epoch 60/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0046 - lr: 0.0100
# Epoch 61/150
#  1/21 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0069
# Epoch 61: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0047 - lr: 0.0100
# Epoch 62/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0046 - lr: 0.0010
# Epoch 63/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0046 - lr: 0.0010
# Epoch 64/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0046 - lr: 0.0010
# Epoch 65/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0046 - lr: 0.0010
# Epoch 66/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0046 - lr: 0.0010
# Epoch 67/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0046 - lr: 0.0010
# Epoch 68/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0047 - lr: 0.0010
# Epoch 69/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0046 - lr: 0.0010
# Epoch 70/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0046 - lr: 0.0010
# Epoch 71/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0046 - lr: 0.0010
# Layer 2 has been pretrained.
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Copying layer-wise pretrained weights to deep autoencoders
# Fine-tuning autoencoder end-to-end
# Epoch 1/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.0288 - lr: 0.1000
# Epoch 2/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0253 - lr: 0.1000
# Epoch 3/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0238 - lr: 0.1000
# Epoch 4/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0230 - lr: 0.1000
# Epoch 5/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0224 - lr: 0.1000
# Epoch 6/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0219 - lr: 0.1000
# Epoch 7/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0215 - lr: 0.1000
# Epoch 8/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0212 - lr: 0.1000
# Epoch 9/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0209 - lr: 0.1000
# Epoch 10/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0206 - lr: 0.1000
# Epoch 11/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0203 - lr: 0.1000
# Epoch 12/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0200 - lr: 0.1000
# Epoch 13/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0198 - lr: 0.1000
# Epoch 14/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0195 - lr: 0.1000
# Epoch 15/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0193 - lr: 0.1000
# Epoch 16/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0191 - lr: 0.1000
# Epoch 17/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0189 - lr: 0.1000
# Epoch 18/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0187 - lr: 0.1000
# Epoch 19/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0185 - lr: 0.1000
# Epoch 20/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0183 - lr: 0.1000
# Epoch 21/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0181 - lr: 0.1000
# Epoch 22/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0179 - lr: 0.1000
# Epoch 23/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0177 - lr: 0.1000
# Epoch 24/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0176 - lr: 0.1000
# Epoch 25/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0174 - lr: 0.1000
# Epoch 26/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0172 - lr: 0.1000
# Epoch 27/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0171 - lr: 0.1000
# Epoch 28/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0169 - lr: 0.1000
# Epoch 29/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0168 - lr: 0.1000
# Epoch 30/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0167 - lr: 0.1000
# Epoch 31/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0165 - lr: 0.1000
# Epoch 32/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0164 - lr: 0.1000
# Epoch 33/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0163 - lr: 0.1000
# Epoch 34/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0161 - lr: 0.1000
# Epoch 35/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0160 - lr: 0.1000
# Epoch 36/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0159 - lr: 0.1000
# Epoch 37/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0158 - lr: 0.1000
# Epoch 38/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0157 - lr: 0.1000
# Epoch 39/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0156 - lr: 0.1000
# Epoch 40/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0155 - lr: 0.1000
# Epoch 41/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0154 - lr: 0.1000
# Epoch 42/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0153 - lr: 0.1000
# Epoch 43/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0152 - lr: 0.1000
# Epoch 44/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0151 - lr: 0.1000
# Epoch 45/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0150 - lr: 0.1000
# Epoch 46/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0149 - lr: 0.1000
# Epoch 47/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0148 - lr: 0.1000
# Epoch 48/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0147 - lr: 0.1000
# Epoch 49/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0146 - lr: 0.1000
# Epoch 50/300
#  1/21 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0189
# Epoch 50: ReduceLROnPlateau reducing learning rate to 0.009999999776482582
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0145 - lr: 0.1000
# Epoch 51/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0144 - lr: 0.0100
# Epoch 52/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0144 - lr: 0.0100
# Epoch 53/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0144 - lr: 0.0100
# Epoch 54/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0144 - lr: 0.0100
# Epoch 55/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0144 - lr: 0.0100
# Epoch 56/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0144 - lr: 0.0100
# Epoch 57/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0144 - lr: 0.0100
# Epoch 58/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0143 - lr: 0.0100
# Epoch 59/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0143 - lr: 0.0100
# Epoch 60/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0143 - lr: 0.0100
# Epoch 61/300
#  1/21 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0186
# Epoch 61: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0143 - lr: 0.0100
# Epoch 62/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0143 - lr: 0.0010
# Epoch 63/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0143 - lr: 0.0010
# Epoch 64/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0143 - lr: 0.0010
# Epoch 65/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0143 - lr: 0.0010
# Epoch 66/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0143 - lr: 0.0010
# Epoch 67/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0143 - lr: 0.0010
# Epoch 68/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0143 - lr: 0.0010
# Epoch 69/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0143 - lr: 0.0010
# Epoch 70/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0143 - lr: 0.0010
# Epoch 71/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0143 - lr: 0.0010
# Epoch 72/300
#  1/21 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0186
# Epoch 72: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0143 - lr: 0.0010
# Epoch 73/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0143 - lr: 1.0000e-04
# Epoch 74/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0143 - lr: 1.0000e-04
# Epoch 75/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0143 - lr: 1.0000e-04
# Epoch 76/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0143 - lr: 1.0000e-04
# Epoch 77/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0143 - lr: 1.0000e-04
# Epoch 78/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0143 - lr: 1.0000e-04
# Epoch 79/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0143 - lr: 1.0000e-04
# Epoch 80/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0143 - lr: 1.0000e-04
# Epoch 81/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0143 - lr: 1.0000e-04
# Epoch 82/300
#  1/21 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0186
# Epoch 82: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0143 - lr: 1.0000e-04
# Epoch 83/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0143 - lr: 1.0000e-05
# Epoch 84/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0143 - lr: 1.0000e-05
# Epoch 85/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0143 - lr: 1.0000e-05
# Epoch 86/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0143 - lr: 1.0000e-05
# Epoch 87/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0143 - lr: 1.0000e-05
# Epoch 88/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0143 - lr: 1.0000e-05
# Epoch 89/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0143 - lr: 1.0000e-05
# Epoch 90/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0143 - lr: 1.0000e-05
# Epoch 91/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0143 - lr: 1.0000e-05
# Epoch 92/300
#  1/21 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0186
# Epoch 92: ReduceLROnPlateau reducing learning rate to 1e-06.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0143 - lr: 1.0000e-05
# Epoch 93/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0143 - lr: 1.0000e-06
# Epoch 94/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0143 - lr: 1.0000e-06
# Epoch 95/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0143 - lr: 1.0000e-06
# Epoch 96/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0143 - lr: 1.0000e-06
# Epoch 97/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0143 - lr: 1.0000e-06
# Epoch 98/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0143 - lr: 1.0000e-06
# Epoch 99/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0143 - lr: 1.0000e-06
# Epoch 100/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0143 - lr: 1.0000e-06
# Epoch 101/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0143 - lr: 1.0000e-06
# Epoch 102/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0143 - lr: 1.0000e-06
# Pretraining time (HH:MM:SS): 0:00:31.026719
# Pretrained weights are saved to /scratch/g/tgu/svenkatesan/Other/SCREAM_wf/results/scream_cellline_hyper_large_new2/RNA_ATAC_joint/ae.weights.h5
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# ...number of clusters is unknown, Initialize cluster centroid using leiden method
# /home/svenkatesan/.conda/envs/Shri_NN/lib/python3.12/functools.py:909: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /home/svenkatesan/.conda/envs/Shri_NN/lib/python3.12/functools.py:909: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /scratch/g/tgu/svenkatesan/Other/SCREAM_wf/SCREAM/models/network.py:232: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata0, resolution=self.resolution)
# The value of delta_label of current 1th iteration is: 0.051575932651758194 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0899
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0744
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0644
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0572
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0513
# The value of delta_label of current 2th iteration is: 0.03915950283408165 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1206
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1073
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0962
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0870
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0792
# The value of delta_label of current 3th iteration is: 0.012416427955031395 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1365
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1251
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1151
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1066
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0992
# The value of delta_label of current 4th iteration is: 0.008595988154411316 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1417
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1329
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1250
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1180
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1118
# The value of delta_label of current 5th iteration is: 0.006685768719762564 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1410
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1342
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1281
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1225
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1175
# The value of delta_label of current 6th iteration is: 0.0019102196674793959 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1377
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1325
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1276
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1231
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1189
# The value of delta_label of current 7th iteration is: 0.0028653296176344156 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1336
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1294
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1254
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1217
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1182
# The value of delta_label of current 8th iteration is: 0.005730659235268831 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1293
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1258
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1225
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1194
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1164
# The value of delta_label of current 9th iteration is: 0.0019102196674793959 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1251
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1222
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1193
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1166
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1140
# delta_label 0.0 < tol 0.0001
# Reached tolerance threshold. Stop training.
# The final prediction cluster is:
# 0    390
# 1    320
# 2    199
# 3    138
# Name: count, dtype: int64
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# DESC has been trained successfully!!!!!!
# The summary of desc model is:
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input (InputLayer)              │ (None, 248)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ encoder_0 (Dense)               │ (None, 1024)           │       254,976 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ encoder_1 (Dense)               │ (None, 236)            │       241,900 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ clustering (ClusteringLayer)    │ (None, 4)              │           944 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 995,642 (3.80 MB)
#  Trainable params: 497,820 (1.90 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 497,822 (1.90 MB)
# UMAP finished and added X_umap0.1 into adata.obsm
# /home/svenkatesan/.conda/envs/Shri_NN/lib/python3.12/site-packages/legacy_api_wrap/__init__.py:82: UserWarning: In previous versions of scanpy, calling tsne with n_jobs > 1 would use MulticoreTSNE. Now this uses the scikit-learn version of TSNE by default. If you'd like the old behaviour (which is deprecated), pass 'use_fast_tsne=True'. Note, MulticoreTSNE is not actually faster anymore.
#   return fn(*args_all, **kw)
# TSNE finished and added X_tsne0.1 into adata.obsm
#
# Start to process resolution: 0.2
# Training will be done on CPU.
# Runtime for resolution 0.2 (HH:MM:SS): 0:00:00.000024
# Pretraining time (HH:MM:SS): 0:00:00.039212
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# ...number of clusters is unknown, Initialize cluster centroid using leiden method
# /home/svenkatesan/.conda/envs/Shri_NN/lib/python3.12/functools.py:909: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /home/svenkatesan/.conda/envs/Shri_NN/lib/python3.12/functools.py:909: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# The value of delta_label of current 1th iteration is: 0.04966571182012558 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0899
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0744
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0644
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0572
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0513
# The value of delta_label of current 2th iteration is: 0.037249282002449036 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1206
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1073
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0962
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0870
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0792
# The value of delta_label of current 3th iteration is: 0.011461318470537663 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1365
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1251
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1151
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1065
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0991
# The value of delta_label of current 4th iteration is: 0.008595988154411316 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1417
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1329
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1250
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1180
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1117
# The value of delta_label of current 5th iteration is: 0.006685768719762564 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1409
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1342
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1281
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1225
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1174
# The value of delta_label of current 6th iteration is: 0.0028653296176344156 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1377
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1324
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1276
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1231
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1189
# The value of delta_label of current 7th iteration is: 0.0038204393349587917 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1336
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1294
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1254
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1217
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1182
# The value of delta_label of current 8th iteration is: 0.0047755492851138115 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1293
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1258
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1225
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1194
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1164
# The value of delta_label of current 9th iteration is: 0.0009551098337396979 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1251
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1222
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1193
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1166
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1140
# delta_label 0.0 < tol 0.0001
# Reached tolerance threshold. Stop training.
# The final prediction cluster is:
# 0    390
# 1    320
# 2    199
# 3    138
# Name: count, dtype: int64
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# DESC has been trained successfully!!!!!!
# The summary of desc model is:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input (InputLayer)              │ (None, 248)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ encoder_0 (Dense)               │ (None, 1024)           │       254,976 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ encoder_1 (Dense)               │ (None, 236)            │       241,900 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ clustering (ClusteringLayer)    │ (None, 4)              │           944 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 995,642 (3.80 MB)
#  Trainable params: 497,820 (1.90 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 497,822 (1.90 MB)
# UMAP finished and added X_umap0.2 into adata.obsm
# /home/svenkatesan/.conda/envs/Shri_NN/lib/python3.12/site-packages/legacy_api_wrap/__init__.py:82: UserWarning: In previous versions of scanpy, calling tsne with n_jobs > 1 would use MulticoreTSNE. Now this uses the scikit-learn version of TSNE by default. If you'd like the old behaviour (which is deprecated), pass 'use_fast_tsne=True'. Note, MulticoreTSNE is not actually faster anymore.
#   return fn(*args_all, **kw)
# TSNE finished and added X_tsne0.2 into adata.obsm
#
# Start to process resolution: 0.3
# Training will be done on CPU.
# Runtime for resolution 0.3 (HH:MM:SS): 0:00:00.000012
# Pretraining time (HH:MM:SS): 0:00:00.036608
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# ...number of clusters is unknown, Initialize cluster centroid using leiden method
# /home/svenkatesan/.conda/envs/Shri_NN/lib/python3.12/functools.py:909: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /home/svenkatesan/.conda/envs/Shri_NN/lib/python3.12/functools.py:909: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# The value of delta_label of current 1th iteration is: 0.18051576614379883 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.1183
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1034
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0927
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0841
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0767
# The value of delta_label of current 2th iteration is: 0.04584527388215065 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1500
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1372
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1260
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1165
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1082
# The value of delta_label of current 3th iteration is: 0.025787966325879097 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1677
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1567
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1470
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1384
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1309
# The value of delta_label of current 4th iteration is: 0.014326647855341434 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1749
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1661
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1582
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1511
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1447
# The value of delta_label of current 5th iteration is: 0.011461318470537663 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1763
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1693
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1628
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1570
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1516
# The value of delta_label of current 6th iteration is: 0.0076408786699175835 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1747
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1690
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1637
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1588
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1543
# The value of delta_label of current 7th iteration is: 0.0038204393349587917 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1717
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1670
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1626
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1585
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1547
# The value of delta_label of current 8th iteration is: 0.0076408786699175835 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1682
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1642
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1605
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1570
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1537
# The value of delta_label of current 9th iteration is: 0.008595988154411316 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1644
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1611
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1579
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1549
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1520
# The value of delta_label of current 10th iteration is: 0.0028653296176344156 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1608
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1578
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1551
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1524
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1499
# The value of delta_label of current 11th iteration is: 0.0038204393349587917 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1572
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1546
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1522
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1498
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1476
# The value of delta_label of current 12th iteration is: 0.0038204393349587917 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1539
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1515
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1493
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1472
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1452
# The value of delta_label of current 13th iteration is: 0.0047755492851138115 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1507
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1486
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1466
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1446
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1428
# The value of delta_label of current 14th iteration is: 0.0028653296176344156 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1476
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1457
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1439
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1421
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1404
# delta_label 0.0 < tol 0.0001
# Reached tolerance threshold. Stop training.
# The final prediction cluster is:
# 0    283
# 1    247
# 2    172
# 3    213
# 4    132
# Name: count, dtype: int64
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# DESC has been trained successfully!!!!!!
# The summary of desc model is:
# Model: "functional_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input (InputLayer)              │ (None, 248)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ encoder_0 (Dense)               │ (None, 1024)           │       254,976 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ encoder_1 (Dense)               │ (None, 236)            │       241,900 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ clustering (ClusteringLayer)    │ (None, 5)              │         1,180 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 996,114 (3.80 MB)
#  Trainable params: 498,056 (1.90 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 498,058 (1.90 MB)
# UMAP finished and added X_umap0.3 into adata.obsm
# /home/svenkatesan/.conda/envs/Shri_NN/lib/python3.12/site-packages/legacy_api_wrap/__init__.py:82: UserWarning: In previous versions of scanpy, calling tsne with n_jobs > 1 would use MulticoreTSNE. Now this uses the scikit-learn version of TSNE by default. If you'd like the old behaviour (which is deprecated), pass 'use_fast_tsne=True'. Note, MulticoreTSNE is not actually faster anymore.
#   return fn(*args_all, **kw)
# TSNE finished and added X_tsne0.3 into adata.obsm
#
# Start to process resolution: 0.4
# Training will be done on CPU.
# Runtime for resolution 0.4 (HH:MM:SS): 0:00:00.000016
# Pretraining time (HH:MM:SS): 0:00:00.038247
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# ...number of clusters is unknown, Initialize cluster centroid using leiden method
# /home/svenkatesan/.conda/envs/Shri_NN/lib/python3.12/functools.py:909: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /home/svenkatesan/.conda/envs/Shri_NN/lib/python3.12/functools.py:909: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# The value of delta_label of current 1th iteration is: 0.11079274117946625 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.1286
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1123
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1025
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0947
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0880
# The value of delta_label of current 2th iteration is: 0.06590257585048676 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1643
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1507
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1405
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1317
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1240
# The value of delta_label of current 3th iteration is: 0.044890161603689194 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1850
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1735
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1645
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1564
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1492
# The value of delta_label of current 4th iteration is: 0.030563514679670334 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1950
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1856
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1779
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1709
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1646
# The value of delta_label of current 5th iteration is: 0.03247373551130295 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1985
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1908
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1844
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1784
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1730
# The value of delta_label of current 6th iteration is: 0.03247373551130295 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1985
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1922
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1867
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1816
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1769
# The value of delta_label of current 7th iteration is: 0.02101241610944271 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1967
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1915
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1867
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1822
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1781
# The value of delta_label of current 8th iteration is: 0.012416427955031395 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1938
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1894
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1852
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1813
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1777
# The value of delta_label of current 9th iteration is: 0.016236867755651474 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1903
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1864
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1828
# Epoch 4/5
# ...
# The summary of desc model is:
# Model: "functional_13"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input (InputLayer)              │ (None, 248)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ encoder_0 (Dense)               │ (None, 1024)           │       254,976 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ encoder_1 (Dense)               │ (None, 236)            │       241,900 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ clustering (ClusteringLayer)    │ (None, 9)              │         2,124 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 998,002 (3.81 MB)
#  Trainable params: 499,000 (1.90 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 499,002 (1.90 MB)
# UMAP finished and added X_umap1.0 into adata.obsm
# /home/svenkatesan/.conda/envs/Shri_NN/lib/python3.12/site-packages/legacy_api_wrap/__init__.py:82: UserWarning: In previous versions of scanpy, calling tsne with n_jobs > 1 would use MulticoreTSNE. Now this uses the scikit-learn version of TSNE by default. If you'd like the old behaviour (which is deprecated), pass 'use_fast_tsne=True'. Note, MulticoreTSNE is not actually faster anymore.
#   return fn(*args_all, **kw)
# TSNE finished and added X_tsne1.0 into adata.obsm
#
# Start to process resolution: 0.05
# Training will be done on CPU.
# Runtime for resolution 0.05 (HH:MM:SS): 0:00:00.000013
# Pretraining time (HH:MM:SS): 0:00:00.038618
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# ...number of clusters is unknown, Initialize cluster centroid using leiden method
# /home/svenkatesan/.conda/envs/Shri_NN/lib/python3.12/functools.py:909: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /home/svenkatesan/.conda/envs/Shri_NN/lib/python3.12/functools.py:909: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# The value of delta_label of current 1th iteration is: 0.014326647855341434 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0243
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0186
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0158
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0144
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0135
# The value of delta_label of current 2th iteration is: 0.0047755492851138115 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0309
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0273
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0247
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0229
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0214
# The value of delta_label of current 3th iteration is: 0.0047755492851138115 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0341
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0314
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0292
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0273
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0258
# The value of delta_label of current 4th iteration is: 0.0019102196674793959 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0362
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0338
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0316
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0298
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0282
# The value of delta_label of current 5th iteration is: 0.0047755492851138115 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0387
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0359
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0337
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0318
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0302
# The value of delta_label of current 6th iteration is: 0.043935053050518036 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0421
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0382
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0354
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0332
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0313
# The value of delta_label of current 7th iteration is: 0.041069723665714264 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0464
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0407
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0372
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0346
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0326
# The value of delta_label of current 8th iteration is: 0.03247373551130295 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0487
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0437
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0406
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0384
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0365
# The value of delta_label of current 9th iteration is: 0.022922636941075325 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0487
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0453
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0431
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0412
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0397
# The value of delta_label of current 10th iteration is: 0.015281757339835167 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0478
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0453
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0437
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0422
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0410
# The value of delta_label of current 11th iteration is: 0.009551098570227623 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0464
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0445
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0432
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0421
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0410
# The value of delta_label of current 12th iteration is: 0.008595988154411316 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0450
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0435
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0424
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0414
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0406
# The value of delta_label of current 13th iteration is: 0.010506208054721355 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0439
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0426
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0416
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0408
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0400
# The value of delta_label of current 14th iteration is: 0.008595988154411316 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0428
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0417
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0408
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0401
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0394
# The value of delta_label of current 15th iteration is: 0.006685768719762564 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0416
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0407
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0400
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0393
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0387
# The value of delta_label of current 16th iteration is: 0.0038204393349587917 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0405
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0397
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0390
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0384
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0379
# The value of delta_label of current 17th iteration is: 0.0038204393349587917 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0394
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0387
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0381
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0376
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0371
# The value of delta_label of current 18th iteration is: 0.0028653296176344156 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0385
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0378
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0373
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0368
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0363
# The value of delta_label of current 19th iteration is: 0.0038204393349587917 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0377
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0370
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0365
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0361
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0356
# The value of delta_label of current 20th iteration is: 0.005730659235268831 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0369
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0363
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0359
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0354
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0350
# The value of delta_label of current 21th iteration is: 0.0038204393349587917 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0363
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0357
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0352
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0348
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0344
# The value of delta_label of current 22th iteration is: 0.0019102196674793959 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0356
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0351
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0346
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0343
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0339
# The value of delta_label of current 23th iteration is: 0.006685768719762564 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0350
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0345
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0341
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0337
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0334
# The value of delta_label of current 24th iteration is: 0.0028653296176344156 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0344
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0339
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0335
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0332
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0329
# The value of delta_label of current 25th iteration is: 0.0028653296176344156 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0338
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0334
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0330
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0327
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0323
# The value of delta_label of current 26th iteration is: 0.0019102196674793959 >= tol 0.0001
# Epoch 1/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0332
# Epoch 2/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0328
# Epoch 3/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0325
# Epoch 4/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0322
# Epoch 5/5
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0319
# delta_label 0.0 < tol 0.0001
# Reached tolerance threshold. Stop training.
# The final prediction cluster is:
# 0    651
# 1    396
# Name: count, dtype: int64
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# DESC has been trained successfully!!!!!!
# The summary of desc model is:
# Model: "functional_14"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input (InputLayer)              │ (None, 248)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ encoder_0 (Dense)               │ (None, 1024)           │       254,976 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ encoder_1 (Dense)               │ (None, 236)            │       241,900 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ clustering (ClusteringLayer)    │ (None, 2)              │           472 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 994,698 (3.79 MB)
#  Trainable params: 497,348 (1.90 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 497,350 (1.90 MB)
# UMAP finished and added X_umap0.05 into adata.obsm
# /home/svenkatesan/.conda/envs/Shri_NN/lib/python3.12/site-packages/legacy_api_wrap/__init__.py:82: UserWarning: In previous versions of scanpy, calling tsne with n_jobs > 1 would use MulticoreTSNE. Now this uses the scikit-learn version of TSNE by default. If you'd like the old behaviour (which is deprecated), pass 'use_fast_tsne=True'. Note, MulticoreTSNE is not actually faster anymore.
#   return fn(*args_all, **kw)
# TSNE finished and added X_tsne0.05 into adata.obsm
#
# Total time to run DESC (HH:MM:SS): 0:04:54.915920
# MuData object with n_obs × n_vars = 1047 × 7636
#   obs:	'desc_0.1', 'desc_0.2', 'desc_0.3', 'desc_0.4', 'desc_0.5', 'desc_0.6', 'desc_0.7', 'desc_0.8', 'desc_0.9', 'desc_1.0', 'desc_0.05'
#   uns:	'prob_matrix0.1', 'umap', 'tsne', 'prob_matrix0.2', 'prob_matrix0.3', 'prob_matrix0.4', 'prob_matrix0.5', 'prob_matrix0.6', 'prob_matrix0.7', 'prob_matrix0.8', 'prob_matrix0.9', 'prob_matrix1.0', 'prob_matrix0.05'
#   obsm:	'joint_ls', 'X_Embedded_z0.1', 'X_umap', 'X_umap0.1', 'X_tsne', 'X_tsne0.1', 'X_Embedded_z0.2', 'X_umap0.2', 'X_tsne0.2', 'X_Embedded_z0.3', 'X_umap0.3', 'X_tsne0.3', 'X_Embedded_z0.4', 'X_umap0.4', 'X_tsne0.4', 'X_Embedded_z0.5', 'X_umap0.5', 'X_tsne0.5', 'X_Embedded_z0.6', 'X_umap0.6', 'X_tsne0.6', 'X_Embedded_z0.7', 'X_umap0.7', 'X_tsne0.7', 'X_Embedded_z0.8', 'X_umap0.8', 'X_tsne0.8', 'X_Embedded_z0.9', 'X_umap0.9', 'X_tsne0.9', 'X_Embedded_z1.0', 'X_umap1.0', 'X_tsne1.0', 'X_Embedded_z0.05', 'X_umap0.05', 'X_tsne0.05'
#   2 modalities
#     RNA:	1047 x 500
#       obs:	'cell_line'
#       uns:	'desc_ls_hparams'
#       obsm:	'X_desc_ls'
#     ATAC:	1047 x 7136
#       obs:	'cell_line'
#       uns:	'desc_ls_hparams'
#       obsm:	'X_desc_ls'

# %%
# SCREAM.models.tools.plot_architecture(ae_combined.model, to_file=os.path.join(model_result_dir, 'joint_ae.svg'), rankdir='LR')

# %%
display(scream_model.mdata_train)
# Out:
# MuData object with n_obs × n_vars = 1047 × 7636
#   obs:	'desc_0.1', 'desc_0.2', 'desc_0.3', 'desc_0.4', 'desc_0.5', 'desc_0.6', 'desc_0.7', 'desc_0.8', 'desc_0.9', 'desc_1.0', 'desc_0.05'
#   uns:	'prob_matrix0.1', 'umap', 'tsne', 'prob_matrix0.2', 'prob_matrix0.3', 'prob_matrix0.4', 'prob_matrix0.5', 'prob_matrix0.6', 'prob_matrix0.7', 'prob_matrix0.8', 'prob_matrix0.9', 'prob_matrix1.0', 'prob_matrix0.05'
#   obsm:	'joint_ls', 'X_Embedded_z0.1', 'X_umap', 'X_umap0.1', 'X_tsne', 'X_tsne0.1', 'X_Embedded_z0.2', 'X_umap0.2', 'X_tsne0.2', 'X_Embedded_z0.3', 'X_umap0.3', 'X_tsne0.3', 'X_Embedded_z0.4', 'X_umap0.4', 'X_tsne0.4', 'X_Embedded_z0.5', 'X_umap0.5', 'X_tsne0.5', 'X_Embedded_z0.6', 'X_umap0.6', 'X_tsne0.6', 'X_Embedded_z0.7', 'X_umap0.7', 'X_tsne0.7', 'X_Embedded_z0.8', 'X_umap0.8', 'X_tsne0.8', 'X_Embedded_z0.9', 'X_umap0.9', 'X_tsne0.9', 'X_Embedded_z1.0', 'X_umap1.0', 'X_tsne1.0', 'X_Embedded_z0.05', 'X_umap0.05', 'X_tsne0.05'
#   2 modalities
#     RNA:	1047 x 500
#       obs:	'cell_line'
#       uns:	'desc_ls_hparams'
#       obsm:	'X_desc_ls'
#     ATAC:	1047 x 7136
#       obs:	'cell_line'
#       uns:	'desc_ls_hparams'
#       obsm:	'X_desc_ls'

# %%
mm_model = scream_model.build_endtoend([sae_rna, sae_atac], ae_combined.model)

# %%
SCREAM.models.tools.plot_architecture(mm_model, to_file=os.path.join(model_result_dir, 'joint_ae_full.svg'), rankdir='LR')
# Out:
# {'rankdir': 'LR'}
# You must install graphviz (see instructions at https://graphviz.gitlab.io/download/) for `plot_model` to work.

# %% [markdown]
# ## Plot cluster evaluation metrics

# %%
ari_pd = SCREAM.models.tools.calc_ari(scream_model.mdata_train, label_col='RNA:cell_line', cluster_res=leiden_res)
nmi_pd = SCREAM.models.tools.calc_nmi(scream_model.mdata_train, label_col='RNA:cell_line', cluster_res=leiden_res)
sil_pd = SCREAM.models.tools.calc_silhouette(scream_model.mdata_train, cluster_res=leiden_res)
metrics_df = ari_pd.join([nmi_pd, sil_pd])

# %%
display(metrics_df.sort_index().style.set_caption('<b>Evaluated clustering metrics</b>').
        set_table_styles([{'selector': 'th:not(.index_name)', 'props': 'background-color: #000000; color: white;border-left: 1px solid white;'},
                          {'selector': 'td', 'props': 'border: 1px solid black;'}]).
        background_gradient(axis=0, cmap="Blues"))
# Out:
# <style type="text/css">
# #T_92055 th:not(.index_name) {
#   background-color: #000000;
#   color: white;
#   border-left: 1px solid white;
# }
# #T_92055 td {
#   border: 1px solid black;
# }
# #T_92055_row0_col0, #T_92055_row0_col1, #T_92055_row10_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_92055_row0_col2, #T_92055_row1_col0, #T_92055_row1_col1, #T_92055_row2_col0, #T_92055_row2_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_92055_row1_col2 {
#   background-color: #64a9d3;
#   color: #f1f1f1;
# }
# #T_92055_row2_col2, #T_92055_row5_col2 {
#   background-color: #63a8d3;
#   color: #f1f1f1;
# }
# #T_92055_row3_col0 {
#   background-color: #5da5d1;
#   color: #f1f1f1;
# }
# #T_92055_row3_col1 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_92055_row3_col2 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_92055_row4_col0 {
#   background-color: #75b4d8;
#   color: #000000;
# }
# #T_92055_row4_col1 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_92055_row4_col2 {
#   background-color: #7cb7da;
#   color: #000000;
# }
# #T_92055_row5_col0 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_92055_row5_col1 {
#   background-color: #3484bf;
#   color: #f1f1f1;
# }
# #T_92055_row6_col0 {
#   background-color: #87bddc;
#   color: #000000;
# }
# #T_92055_row6_col1 {
#   background-color: #3686c0;
#   color: #f1f1f1;
# }
# #T_92055_row6_col2 {
#   background-color: #b4d3e9;
#   color: #000000;
# }
# #T_92055_row7_col0 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_92055_row7_col1, #T_92055_row10_col1 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_92055_row7_col2 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_92055_row8_col0 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_92055_row8_col1 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_92055_row8_col2 {
#   background-color: #60a7d2;
#   color: #f1f1f1;
# }
# #T_92055_row9_col0, #T_92055_row10_col0 {
#   background-color: #d7e6f5;
#   color: #000000;
# }
# #T_92055_row9_col1 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# #T_92055_row9_col2 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_92055">
#   <caption><b>Evaluated clustering metrics</b></caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_92055_level0_col0" class="col_heading level0 col0" >ARI</th>
#       <th id="T_92055_level0_col1" class="col_heading level0 col1" >NMI</th>
#       <th id="T_92055_level0_col2" class="col_heading level0 col2" >Silhouette Score</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >cluster resolution</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_92055_level0_row0" class="row_heading level0 row0" >0.050000</th>
#       <td id="T_92055_row0_col0" class="data row0 col0" >0.367172</td>
#       <td id="T_92055_row0_col1" class="data row0 col1" >0.466307</td>
#       <td id="T_92055_row0_col2" class="data row0 col2" >0.783300</td>
#     </tr>
#     <tr>
#       <th id="T_92055_level0_row1" class="row_heading level0 row1" >0.100000</th>
#       <td id="T_92055_row1_col0" class="data row1 col0" >0.944107</td>
#       <td id="T_92055_row1_col1" class="data row1 col1" >0.909666</td>
#       <td id="T_92055_row1_col2" class="data row1 col2" >0.652706</td>
#     </tr>
#     <tr>
#       <th id="T_92055_level0_row2" class="row_heading level0 row2" >0.200000</th>
#       <td id="T_92055_row2_col0" class="data row2 col0" >0.944107</td>
#       <td id="T_92055_row2_col1" class="data row2 col1" >0.909666</td>
#       <td id="T_92055_row2_col2" class="data row2 col2" >0.652969</td>
#     </tr>
#     <tr>
#       <th id="T_92055_level0_row3" class="row_heading level0 row3" >0.300000</th>
#       <td id="T_92055_row3_col0" class="data row3 col0" >0.679724</td>
#       <td id="T_92055_row3_col1" class="data row3 col1" >0.748441</td>
#       <td id="T_92055_row3_col2" class="data row3 col2" >0.588842</td>
#     </tr>
#     <tr>
#       <th id="T_92055_level0_row4" class="row_heading level0 row4" >0.400000</th>
#       <td id="T_92055_row4_col0" class="data row4 col0" >0.640819</td>
#       <td id="T_92055_row4_col1" class="data row4 col1" >0.794116</td>
#       <td id="T_92055_row4_col2" class="data row4 col2" >0.635316</td>
#     </tr>
#     <tr>
#       <th id="T_92055_level0_row5" class="row_heading level0 row5" >0.500000</th>
#       <td id="T_92055_row5_col0" class="data row5 col0" >0.620539</td>
#       <td id="T_92055_row5_col1" class="data row5 col1" >0.766497</td>
#       <td id="T_92055_row5_col2" class="data row5 col2" >0.653086</td>
#     </tr>
#     <tr>
#       <th id="T_92055_level0_row6" class="row_heading level0 row6" >0.600000</th>
#       <td id="T_92055_row6_col0" class="data row6 col0" >0.617043</td>
#       <td id="T_92055_row6_col1" class="data row6 col1" >0.763321</td>
#       <td id="T_92055_row6_col2" class="data row6 col2" >0.593791</td>
#     </tr>
#     <tr>
#       <th id="T_92055_level0_row7" class="row_heading level0 row7" >0.700000</th>
#       <td id="T_92055_row7_col0" class="data row7 col0" >0.475032</td>
#       <td id="T_92055_row7_col1" class="data row7 col1" >0.683679</td>
#       <td id="T_92055_row7_col2" class="data row7 col2" >0.550457</td>
#     </tr>
#     <tr>
#       <th id="T_92055_level0_row8" class="row_heading level0 row8" >0.800000</th>
#       <td id="T_92055_row8_col0" class="data row8 col0" >0.477689</td>
#       <td id="T_92055_row8_col1" class="data row8 col1" >0.689060</td>
#       <td id="T_92055_row8_col2" class="data row8 col2" >0.655226</td>
#     </tr>
#     <tr>
#       <th id="T_92055_level0_row9" class="row_heading level0 row9" >0.900000</th>
#       <td id="T_92055_row9_col0" class="data row9 col0" >0.460730</td>
#       <td id="T_92055_row9_col1" class="data row9 col1" >0.686480</td>
#       <td id="T_92055_row9_col2" class="data row9 col2" >0.650934</td>
#     </tr>
#     <tr>
#       <th id="T_92055_level0_row10" class="row_heading level0 row10" >1.000000</th>
#       <td id="T_92055_row10_col0" class="data row10 col0" >0.461788</td>
#       <td id="T_92055_row10_col1" class="data row10 col1" >0.684333</td>
#       <td id="T_92055_row10_col2" class="data row10 col2" >0.509786</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig = SCREAM.models.tools.plot_clustereval(metrics_df, res_col='cluster resolution', met_cols=None, ncols=5, figsize=None)
fig
# Out:
# {}

# %%
mu.pl.embedding(scream_model.mdata_train, basis='X_umap0.1', color=['RNA:cell_line', 'desc_0.1'])

# %%
mu.pl.embedding(scream_model.mdata_train, basis='X_tsne0.1', color=['RNA:cell_line', 'desc_0.1'])

# %%
scream_model.mdata_train.write_h5mu(os.path.join(processedDir, 'scream_cellline_atac.h5mu'))

# %% [markdown]
# ## Optional: Tensorboard visualization

# %%
get_ipython().run_line_magic("load_ext", "tensorboard")
get_ipython().run_line_magic("tensorboard", f"--logdir {os.path.join(hyper_model.log_dir)} --port 6006")
# Out:
#       <iframe id="tensorboard-frame-b61a35c41e1352cd" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-b61a35c41e1352cd");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
